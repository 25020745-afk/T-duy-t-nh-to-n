# %%
#bai1
print("Hello world!")
# Out:
# tôi bị ngu

# %%
#bai2
name=input("Hãy nhập tên của bạn:")
print("Hello ",name)
# Out:
# Hãy nhập tên của bạn:phú
# Hello  phú

# %%
#bai3
a=int(input("hãy nhập số a:"))
b=int(input("hãy nhập số b:"))
print(a+b)
print(a-b)
print(a/b)
print(a//b)
print(a*b)
print(a%b)
# Out:
# hãy nhập số a:3
# hãy nhập số b:2
# 5
# 1
# 1.5
# 1
# 6
# 1

# %%
#bai4
a1,b1,c1,a2,b2,a3=map(int,input("nhập các số ").split(","))
TB=((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print(TB)
# Out:
# nhập các số 1,2,3,4,5,6
# 4.2

# %%
#bai5
a,b=map(int,input("hãy nhập các số ").split(","))
print(a**b)
# Out:
# hãy nhập các số 3,5
# 243

# %%
#bai6
chucai=input()
print("mã unicode là ",ord(chucai))
print("viết hoa là ",chucai.upper())
# Out:
# a
# mã unicode là  97
# viết hoa là  A

# %%
#bai7
A = ((13 ** 2) * 3) + 5
B = 13**2*3 + 5
print("A",A)
print("B",B)
# Out:
# A 512
# B 512

# %%
#bai8
C=float(input('Hãy nhập độ C:'))
F=(9/5)*C+32
print("F",F)
# Out:
# Hãy nhập độ C:3.5
# F 38.3

# %%
#bai9
x=int(input("giá tiền của đồng hồ:"))
y=1.4*x+10
print(y)
# Out:
# giá tiền của đồng hồ:5
# 17.0

# %%
#bai10
x,y,z=input("Hãy nhập tên:").split(",")
print("Hi",x,",",y,"and",z)
# Out:
# Hãy nhập tên:phú,nam,anh
# Hi phú , nam and anh

# %%
#bai11
h=int(input("số giờ"))
m=int(input("số phút"))
print("đổi sang giây",(h*3600+60*m))
# Out:
# số giờ5
# số phút50
# đổi sang giây 21000

# %%
#bai12
n=int(input("độ dài cạnh khối rubik"))
print("số miếng dán riêng lẻ là",(n**2)*6)
# Out:
# độ dài cạnh khối rubik5
# số miếng dán riêng lẻ là 150

# %%
#bai13
a=int(input())
b=int(input())
print(a*b%10)
# Out:
# 2
# 5
# 0

# %%
#bai14
a=5
b=6
a,b=b,a
print(a)
print(b)
# Out:
# 6
# 5

# %%
#bai16
L=input().split(",")
for i in L:
  print(i)
# Out:
# Spring,Summer,Autumn,Winter
# Spring
# Summer
# Autumn
# Winter

# %%
#bai17
print('*\n***\n*****')
# Out:
# *
# ***
# *****

# %%
#bai18
print('### # # ### ###\n# # # # #\n# # # # #\n# # # # #\n# ##  # # ')
# Out:
# ### # # ### ###
# # # # # #
# # # # # #
# # # # # #
# # ##  # #

# %%
#bai19
L=input().split(" ")
for i  in  L:
  print(i)
# Out:
# Monday Tuesday Wednesday Thursday Friday Saturday Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#bai20
L=input().split(" ")
for  i in L:
  print(i)
# Out:
# January February March April May June July August September October November December
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#bai21
for i in range(10):
  print("Hello World")
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
#lab02
#bai1
a=7
b=5
c=a-b
print(c)
# Out:
# 2

# %%
#bai2
city = "Hà Nội"
year = 2025
print("Thành phố: ", city, " - Năm: ", year)
# Out:
# Thành phố:  Hà Nội  - Năm:  2025

# %%
#bai3
n = 4
tong = 0
for i in range(1, n+1):
  tong+= i
print(tong)
# Out:
# 10

# %%
#bai4
numbers=[1,2,3,4]
for i in numbers:
  if i%2==0:
    print(i,"là số chẵn")
  else:
    print(i,"là số lẻ ")
# Out:
# 1 là số lẻ
# 2 là số chẵn
# 3 là số lẻ
# 4 là số chẵn

# %%
#bai5
animals = ["cat", "dog", "cat", "bird"]
count = 0
for a in animals:
count += 1
print("Số phần tử trong danh sách là:", count)
# Out:
#   File "/tmp/ipython-input-4245634653.py", line 5
#     count += 1
#     ^
# IndentationError: expected an indented block after 'for' statement on line 4

# %%
#bai6
=== AI Prediction System ===
1) Sentiment analysis
2) Weather forecast
3) Exit
Please choose an option:
# Out:
#   File "/tmp/ipython-input-1225520403.py", line 3
#     1) Sentiment analysis
#      ^
# SyntaxError: unmatched ')'

# %%
#bai7
num = int(input("Nhập số: "))
if num % 2 == 0:
  print("Chẵn")
else:
   print("Lẻ")
# Out:
# Nhập số: 4
# Chẵn

# %%
#bai8
for i in range(3):
 print("AI đang học lần", i + 1)
 print("Huấn luyện xong!")
# Out:
# AI đang học lần 1
# Huấn luyện xong!
# AI đang học lần 2
# Huấn luyện xong!
# AI đang học lần 3
# Huấn luyện xong!

# %%
#bai9
for x in ["cat", "dog", "fish"]:
    print("Dự đoán con vật:", x)
# Out:
# Dự đoán con vật: cat
# Dự đoán con vật: dog
# Dự đoán con vật: fish

# %%
#bai10
# Simple menu
print("=== AI Prediction System ===")
print("1) Sentiment analysis")
print("2) Weather forecast")
print("3) Exit")
print("Please choose an option:")
